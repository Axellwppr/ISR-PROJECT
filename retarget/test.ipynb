# %%
import joblib

data = joblib.load("./data/test_diffusion_manip_window_120_processed_joints24.p")

# %%
print(data[0]['motion'].shape)
# Out:
# (120, 276)

# %%
import numpy as np
# check shapes
for k in data[0].keys():
    if type(data[0][k]) == list:
        print(k, len(data[0][k]))
    elif type(data[0][k]) == np.ndarray:
        print(k, data[0][k].shape)
# Out:
# betas (1, 16)
# gender ()
# trans2joint (3,)
# rest_offsets (24, 3)
# trans (132, 3)
# root_orient (132, 3)
# pose_body (132, 63)
# obj_scale (132,)
# obj_trans (132, 3, 1)
# obj_rot (132, 3, 3)
# obj_com_pos (132, 3)

# %%
print(data[0]["trans2joint"])
# Out:
# [-0.00054002  0.35757434 -0.03087521]

# %%
import numpy as np
nps = np.load("/home/axell/desktop/11-30-ISR-PROJ/retarget/data/object_bps_npy_files_for_eval_joints24/sub16_clothesstand_000_0.npy")

# %%
nps.shape
# Out:
# (120, 1024, 3)
